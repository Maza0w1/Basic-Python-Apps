# %% [markdown]
# <a href="https://colab.research.google.com/github/Yonnihayes/hello-world/blob/master/Countdown_Timer_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import datetime
import timeit


def countdown_timer(x):
    while x >= 0 :
        x -= 1
        print("{} remaining".format(str(datetime.timedelta(seconds=x))))
        print("\n")
        time.sleep(1)


if __name__ == '__main__':
    print(timeit.timeit(lambda:countdown_timer(120), number=1))
# Out:
# 0:01:59 remaining
#
#
# 0:01:58 remaining
#
#
# 0:01:57 remaining
#
#
# 0:01:56 remaining
#
#
# 0:01:55 remaining
#
#
# 0:01:54 remaining
#
#
# 0:01:53 remaining
#
#
# 0:01:52 remaining
#
#
# 0:01:51 remaining
#
#
# 0:01:50 remaining
#
#
# 0:01:49 remaining
#
#
# 0:01:48 remaining
#
#
# 0:01:47 remaining
#
#
# 0:01:46 remaining
#
#
# 0:01:45 remaining
#
#
# 0:01:44 remaining
#
#
# 0:01:43 remaining
#
#
# 0:01:42 remaining
#
#
# 0:01:41 remaining
#
#
# 0:01:40 remaining
#
#
# 0:01:39 remaining
#
#
# 0:01:38 remaining
#
#
# 0:01:37 remaining
#
#
# 0:01:36 remaining
#
#
# 0:01:35 remaining
#
#
# 0:01:34 remaining
#
#
# 0:01:33 remaining
#
#
# 0:01:32 remaining
#
#
# 0:01:31 remaining
#
#
# 0:01:30 remaining
#
#
# 0:01:29 remaining
#
#
# 0:01:28 remaining
#
#
# 0:01:27 remaining
#
#
# 0:01:26 remaining
#
#
# 0:01:25 remaining
#
#
# 0:01:24 remaining
#
#
# 0:01:23 remaining
#
#
# 0:01:22 remaining
#
#
# 0:01:21 remaining
#
#
# 0:01:20 remaining
#
#
# 0:01:19 remaining
#
#
# 0:01:18 remaining
#
#
# 0:01:17 remaining
#
#
# 0:01:16 remaining
#
#
# 0:01:15 remaining
#
#
# 0:01:14 remaining
#
#
# 0:01:13 remaining
#
#
# 0:01:12 remaining
#
#
# 0:01:11 remaining
#
#
# 0:01:10 remaining
#
#
# 0:01:09 remaining
#
#
# 0:01:08 remaining
#
#
# 0:01:07 remaining
#
#
# 0:01:06 remaining
#
#
# 0:01:05 remaining
#
#
# 0:01:04 remaining
#
#
# 0:01:03 remaining
#
#
# 0:01:02 remaining
#
#
# 0:01:01 remaining
#
#
# 0:01:00 remaining
#
#
# 0:00:59 remaining
#
#
# 0:00:58 remaining
#
#
# 0:00:57 remaining
#
#
# 0:00:56 remaining
#
#
# 0:00:55 remaining
#
#
# 0:00:54 remaining
#
#
# 0:00:53 remaining
#
#
# 0:00:52 remaining
#
#
# 0:00:51 remaining
#
#
# 0:00:50 remaining
#
#
# 0:00:49 remaining
#
#
# 0:00:48 remaining
#
#
# 0:00:47 remaining
#
#
# 0:00:46 remaining
#
#
# 0:00:45 remaining
#
#
# 0:00:44 remaining
#
#
# 0:00:43 remaining
#
#
# 0:00:42 remaining
#
#
# 0:00:41 remaining
#
#
# 0:00:40 remaining
#
#
# 0:00:39 remaining
#
#
# 0:00:38 remaining
#
#
# 0:00:37 remaining
#
#
# 0:00:36 remaining
#
#
# 0:00:35 remaining
#
#
# 0:00:34 remaining
#
#
# 0:00:33 remaining
#
#
# 0:00:32 remaining
#
#
# 0:00:31 remaining
#
#
# 0:00:30 remaining
#
#
# 0:00:29 remaining
#
#
# 0:00:28 remaining
#
#
# 0:00:27 remaining
#
#
# 0:00:26 remaining
#
#
# 0:00:25 remaining
#
#
# 0:00:24 remaining
#
#
# 0:00:23 remaining
#
#
# 0:00:22 remaining
#
#
# 0:00:21 remaining
#
#
# 0:00:20 remaining
#
#
# 0:00:19 remaining
#
#
# 0:00:18 remaining
#
#
# 0:00:17 remaining
#
#
# 0:00:16 remaining
#
#
# 0:00:15 remaining
#
#
# 0:00:14 remaining
#
#
# 0:00:13 remaining
#
#
# 0:00:12 remaining
#
#
# 0:00:11 remaining
#
#
# 0:00:10 remaining
#
#
# 0:00:09 remaining
#
#
# 0:00:08 remaining
#
#
# 0:00:07 remaining
#
#
# 0:00:06 remaining
#
#
# 0:00:05 remaining
#
#
# 0:00:04 remaining
#
#
# 0:00:03 remaining
#
#
# 0:00:02 remaining
#
#
# 0:00:01 remaining
#
#
# 0:00:00 remaining
#
#
# -1 day, 23:59:59 remaining
#
#
# 121.1938908889997
