# %% [markdown]
# <a href="https://colab.research.google.com/github/Yonnihayes/hello-world/blob/master/Plotting_sine_and_cosine_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Plots display occurences in data and outliers. This program is for plotting sine and cosine.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

x = np.arange(0, 4*np.pi, 0.1) # start, stop, step
y = np.sin(x)
z = np.cos(x)

plt.plot(x, y, x, z)
plt.show()

plt.xlabel('x values from 0 to 4pi')
plt.ylabel('sin(x) and cos(x)')
plt.title('Plot of sin and cos from 0 to 4pi')
plt.legend(['sin(x)', 'cos(x)'])
plt.show()
